# %%
using Plots

function f(x::Float64) 
    return x^2
end

x = range(-1, stop=2.00, length=100)
y = x->f(x)

plot(x,y)

# %%
# Golden section search algorithm

function gss(f, a, b, N)
    # The golden ratio
    ϕ = (sqrt(5) - 1)/2.0
    ρ = 1-ϕ
    
    d = (1-ρ)*b + ρ*a
    fd = f(d)
    
    for i in 1:N
        c = ρ*b + (1-ρ)*a
        fc = f(c)
        
        if(fc < fd)
            d, b, fd = c, d, fc
        else 
            a, b = b, c
        end   
    end
    
    return a < b ? (a, b) : (b, a)
end
# Out:
# gss (generic function with 4 methods)

# %%
a, b = gss(f, 0.0, 2.0, 10)
# Out:
# (0.0, 0.016261237511566686)
